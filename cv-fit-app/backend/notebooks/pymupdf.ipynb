# %%
import pymupdf

# %%
pdf = pymupdf.open("/Users/rzy/Desktop/ProjectWithTien/cv-helper/resource/testcv.pdf")

# %%
pdf.metadata
# Out:
# {'format': 'PDF 1.7',
#  'title': 'New Resume (2)',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'creator': 'Enhancv',
#  'producer': 'Enhancv (https://www.enhancv.com)',
#  'creationDate': "D:20260806035701+00'00'",
#  'modDate': 'D:20260806035701Z',
#  'trapped': '',
#  'encryption': None}

# %%
page = pdf[0]

# %%
text = page.get_text("blocks", sort=False)

# %%
for b in text:
    print(b[4], "\n")
# Out:
# NGUYEN THANH MINH DUY
#
#
# AI Engineer / ML Engineer
#
#
# +84 33-545-2060
# ntminhduy123@gmail.com
# minhduy.vercel.app
# Location
#
#
# SUMMARY
#
#
# AI and machine learning researcher with a master's degree and hands-on
# experience developing Transformers, graph neural networks, few-shot
# learning, and open-set recognition models in PyTorch. Experienced in
# designing automated experimentation pipelines, analyzing complex datasets,
# and publishing applied deep-learning research, complemented by two years
# of production software engineering experience
#
#
# EXPERIENCE
#
#
# Independent Builder
#
#
# Bé Đậu – AI Career SaaS
#
#
# 2025 - Present
# Location
#
#
# Company Description
#
#
# Built an AI career platform for the Vietnamese market, including ATS-style
# CV analysis, job-fit evaluation, CV tailoring, and real-time voice mock
# interview practice
# Designed a FastAPI backend for LLM-powered workflows using structured
# ...

# %%
text_dict = page.get_text("dict")

# %%
for b in text_dict["blocks"]:
    if b["type"] == 0:
        print(b)
# Out:
# {'type': 0, 'number': 0, 'flags': 0, 'bbox': (48.84175491333008, 43.90049362182617, 326.5096740722656, 69.456787109375), 'lines': [{'spans': [{'size': 21.566490173339844, 'flags': 4, 'bidi': 0, 'char_flags': 16, 'font': 'Rubik-Medium', 'color': 3420980, 'alpha': 255, 'ascender': 0.9350000023841858, 'descender': -0.25, 'text': 'NGUYEN THANH MINH DUY', 'origin': (48.84175491333008, 64.0651626586914), 'bbox': (48.84175491333008, 43.90049362182617, 326.5096740722656, 69.456787109375)}], 'wmode': 0, 'dir': (1.0, 0.0), 'bbox': (48.84175491333008, 43.90049362182617, 326.5096740722656, 69.456787109375)}]}
# ...
